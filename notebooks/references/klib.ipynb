# %% [markdown]
# # **How to Speed Up Data Cleaning with the klib Python library**
#
# Chanin Nantasenamat
#
# [Data Professor YouTube channel](http://youtube.com/dataprofessor), http://youtube.com/dataprofessor
#
# ---
# **Further reading:**
# * [Andreas Kanz @ Medium](https://medium.com/@akanz)
# * [klib Examples on GitHub](https://github.com/akanz1/klib/tree/main/examples)
# * [klib on Towards Data Science](https://towardsdatascience.com/speed-up-your-data-cleaning-and-preprocessing-with-klib-97191d320f80)
# * [klib Documentation](https://klib.readthedocs.io/en/latest/)

# %% [markdown]
# # **Install klib**

# %%
# ! pip install klib

# %% [markdown]
# # **Missing Values Plot**
#
# Here we can examine the data quality. In other words, how clean is the dataset?
#
# ***missingval_plot()*** - provides a high-level overview of the missing values in a dataset. It pinpoints which columns and rows to examine in more detail.
#
# **Top** portion of the plot shows the aggregate for each column. Summary statistics is displayed on the right most side.
#
# **Bottom** portion of the plot shows the missing values (black colors) in the DataFrame.

# %%
# NFL Dataset
import klib
import pandas as pd

df = pd.read_csv('https://github.com/akanz1/klib/raw/main/examples/NFL_DATASET.csv')
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %% [markdown]
# # **Data Cleaning**
#
# The ***data_cleaning()*** function essentially drops empty and single valued columns as well as empty and duplicate rows.

# %%
df_cleaned = klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (183460, 63) - Remaining NAs: 1757318
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 4
#      of which 1 single valued.     Columns: ['play_attempted']
# Dropped missing values: 520667
# Reduced memory by at least: 65.86 MB (-70.23%)

# %% [markdown]
# # **Correlation Plot**
#
# Here, we can examine the intercorrelation amongst the features.

# %% [markdown]
# ### Display all correlations data.

# %%
klib.corr_plot(df_cleaned, annot=False)
# Out:
# <AxesSubplot: title={'center': 'Feature-correlation (pearson)'}>

# %% [markdown]
# ### Display only positive correlation.

# %%
klib.corr_plot(df_cleaned, split='pos', annot=False)
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.
# <AxesSubplot: title={'center': 'Feature-correlation (pearson)'}>

# %% [markdown]
# ### Display only negative correlation.

# %%
klib.corr_plot(df_cleaned, split='neg', annot=False)
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <AxesSubplot: title={'center': 'Feature-correlation (pearson)'}>

# %% [markdown]
# Display correlation with a target variable of interest

# %%
klib.corr_plot(df_cleaned, target='touchdown')
# Out:
# <AxesSubplot: title={'center': 'Feature-correlation (pearson)'}>

# %% [markdown]
# ### Correlation data matrix

# %%
klib.corr_mat(df_cleaned)
# Out:
# <style type="text/css">
T_6b054_row4_col23, #T_6b054_row4_col24, #T_6b054_row4_col27, #T_6b054_row4_col28, #T_6b054_row4_col29, #T_6b054_row4_col30, #T_6b054_row4_col33, #T_6b054_row4_col37, #T_6b054_row4_col39, #T_6b054_row4_col41, #T_6b054_row4_col44, #T_6b054_row5_col1, #T_6b054_row5_col2, #T_6b054_row5_col3, #T_6b054_row5_col4, #T_6b054_row5_col5, #T_6b054_row5_col6, #T_6b054_row5_col9, #T_6b054_row5_col10, #T_6b054_row5_col14, #T_6b054_row5_col15, #T_6b054_row5_col16, #T_6b054_row5_col17, #T_6b054_row5_col18, #T_6b054_row5_col19, #T_6b054_row5_col21, #T_6b054_row5_col22, #T_6b054_row5_col23, #T_6b054_row5_col25, #T_6b054_row5_col27, #T_6b054_row5_col28, #T_6b054_row5_col29, #T_6b054_row5_col30, #T_6b054_row5_col33, #T_6b054_row5_col36, #T_6b054_row5_col38, #T_6b054_row5_col40, #T_6b054_row5_col44, #T_6b054_row6_col3, #T_6b054_row6_col4, #T_6b054_row6_col5, #T_6b054_row6_col6, #T_6b054_row6_col10, #T_6b054_row6_col13, #T_6b054_row6_col15, #T_6b054_row6_col16, #T_6b054_row6_col17, #T_6b054_row6_col18, #T_6b054_row6_col19, #T_6b054_row6_col20, #T_6b054_row6_col21, #T_6b054_row6_col22, #T_6b054_row6_col23, #T_6b054_row6_col24, #T_6b054_row6_col25, #T_6b054_row6_col26, #T_6b054_row6_col27, #T_6b054_row6_col28, #T_6b054_row6_col29, #T_6b054_row6_col30, #T_6b054_row6_col33, #T_6b054_row6_col36, #T_6b054_row6_col44, #T_6b054_row7_col0, #T_6b054_row7_col1, #T_6b054_row7_col4, #T_6b054_row7_col7, #T_6b054_row7_col8, #T_6b054_row7_col9, #T_6b054_row7_col10, #T_6b054_row7_col11, #T_6b054_row7_col12, #T_6b054_row7_col15, #T_6b054_row7_col16, #T_6b054_row7_col17, #T_6b054_row7_col20, #T_6b054_row7_col21, #T_6b054_row7_col24, #T_6b054_row7_col28, #T_6b054_row7_col30, #T_6b054_row7_col31, #T_6b054_row7_col32, #T_6b054_row7_col33, #T_6b054_ro ...

# %% [markdown]
# # **Distribution Plot**
#
# Displays the distribution plot for columns of interest.

# %%
klib.dist_plot(df_cleaned['win_prob'])
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot: xlabel='win_prob', ylabel='Density'>

# %% [markdown]
# # **Categorical Plot**

# %%
klib.cat_plot(df, figsize=(50,15))
# Out:
# GridSpec(6, 21)

# %% [markdown]
# # **Save Plot as a PDF file**

# %%
plot = klib.corr_plot(df_cleaned, annot=False, figsize=(12,10))

# %%
plot.figure.savefig('figure.pdf')
